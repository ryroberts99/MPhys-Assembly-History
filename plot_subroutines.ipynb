# %% [markdown]
# # Subroutines to Generate Various Parameter Plots

# %% [markdown]
# ## Initialisation and Halo/Subhalo Assembly History

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import matplotlib
# %run tags.ipynb
# %run catalogue_particle_read.ipynb

h = 0.6727
m_sun = 1.989e33
omega_b = 0.0491685
omega_0 = 0.3156
omega_lambda = 0.6844
matplotlib.rcParams['font.family'] = ['Times New Roman']
matplotlib.rcParams.update({'font.size': 22})
plt.rcParams['axes.titlesize'] = 24
# Out:
# <style>.container { width:100% !important; }</style>

# %%
assembly_history_early = {
        "000_z020p000": {"halo":None, "subhalo":None},
        "001_z015p132": {"halo":None, "subhalo":None},
        "002_z009p993": {"halo":7,    "subhalo":0   },
        "003_z008p988": {"halo":5,    "subhalo":0   },
        "004_z008p075": {"halo":4,    "subhalo":0   },
        "005_z007p050": {"halo":1,    "subhalo":2   },
        "006_z005p971": {"halo":2,    "subhalo":1   },
        "007_z005p487": {"halo":1,    "subhalo":0   },
        "008_z005p037": {"halo":2,    "subhalo":0   },
        "009_z004p485": {"halo":4,    "subhalo":0   },
        "010_z003p984": {"halo":1,    "subhalo":1   },
        "011_z003p528": {"halo":1,    "subhalo":0   },
        "012_z003p017": {"halo":1,    "subhalo":0   },
        "013_z002p478": {"halo":1,    "subhalo":0   },
        "014_z002p237": {"halo":1,    "subhalo":0   },
        "015_z002p012": {"halo":1,    "subhalo":0   },
        "016_z001p737": {"halo":None, "subhalo":None},
        "017_z001p487": {"halo":1,    "subhalo":0   },
        "018_z001p259": {"halo":1,    "subhalo":0   },
        "019_z001p004": {"halo":1,    "subhalo":0   },
        "020_z000p865": {"halo":1,    "subhalo":0   },
        "021_z000p736": {"halo":1,    "subhalo":0   },
        "022_z000p615": {"halo":1,    "subhalo":0   },
        "023_z000p503": {"halo":1,    "subhalo":0   },
        "024_z000p366": {"halo":1,    "subhalo":0   },
        "025_z000p271": {"halo":1,    "subhalo":0   },
        "026_z000p183": {"halo":1,    "subhalo":0   },
        "027_z000p101": {"halo":1,    "subhalo":0   },
        "028_z000p000": {"halo":1,    "subhalo":0   }
    }

assembly_history_organic = {
        "000_z020p000": {"halo":None, "subhalo":None},
        "001_z015p132": {"halo":None, "subhalo":None},
        "002_z009p993": {"halo":6,    "subhalo":0   },
        "003_z008p988": {"halo":14,   "subhalo":0   },
        "004_z008p075": {"halo":7,    "subhalo":0   },
        "005_z007p050": {"halo":8,    "subhalo":0   },
        "006_z005p971": {"halo":11,   "subhalo":0   },
        "007_z005p487": {"halo":9,    "subhalo":0   },
        "008_z005p037": {"halo":3,    "subhalo":1   },
        "009_z004p485": {"halo":3,    "subhalo":0   },
        "010_z003p984": {"halo":4,    "subhalo":0   },
        "011_z003p528": {"halo":5,    "subhalo":0   },
        "012_z003p017": {"halo":5,    "subhalo":0   },
        "013_z002p478": {"halo":1,    "subhalo":0   },
        "014_z002p237": {"halo":1,    "subhalo":0   },
        "015_z002p012": {"halo":1,    "subhalo":0   },
        "016_z001p737": {"halo":1,    "subhalo":0   },
        "017_z001p487": {"halo":None, "subhalo":None},
        "018_z001p259": {"halo":1,    "subhalo":0   },
        "019_z001p004": {"halo":1,    "subhalo":0   },
        "020_z000p865": {"halo":1,    "subhalo":0   },
        "021_z000p736": {"halo":1,    "subhalo":0   },
        "022_z000p615": {"halo":1,    "subhalo":0   },
        "023_z000p503": {"halo":1,    "subhalo":0   },
        "024_z000p366": {"halo":1,    "subhalo":0   },
        "025_z000p271": {"halo":1,    "subhalo":0   },
        "026_z000p183": {"halo":1,    "subhalo":0   },
        "027_z000p101": {"halo":1,    "subhalo":0   },
        "028_z000p000": {"halo":1,    "subhalo":0   }
    }


assembly_history_late = {
        "000_z020p000": {"halo":None, "subhalo":None},
        "001_z015p132": {"halo":3,    "subhalo":0   },
        "002_z009p993": {"halo":1,    "subhalo":0   },
        "003_z008p988": {"halo":1,    "subhalo":0   },
        "004_z008p075": {"halo":1,    "subhalo":0   },
        "005_z007p050": {"halo":1,    "subhalo":0   },
        "006_z005p971": {"halo":1,    "subhalo":0   },
        "007_z005p487": {"halo":1,    "subhalo":0   },
        "008_z005p037": {"halo":1,    "subhalo":0   },
        "009_z004p485": {"halo":1,    "subhalo":0   },
        "010_z003p984": {"halo":1,    "subhalo":0   },
        "011_z003p528": {"halo":1,    "subhalo":0   },
        "012_z003p017": {"halo":1,    "subhalo":0   },
        "013_z002p478": {"halo":1,    "subhalo":0   },
        "014_z002p237": {"halo":2,    "subhalo":0   },
        "015_z002p012": {"halo":1,    "subhalo":0   },
        "016_z001p737": {"halo":1,    "subhalo":0   },
        "017_z001p487": {"halo":1,    "subhalo":0   },
        "018_z001p259": {"halo":1,    "subhalo":0   },
        "019_z001p004": {"halo":1,    "subhalo":0   },
        "020_z000p865": {"halo":1,    "subhalo":0   },
        "021_z000p736": {"halo":1,    "subhalo":0   },
        "022_z000p615": {"halo":1,    "subhalo":0   },
        "023_z000p503": {"halo":1,    "subhalo":0   },
        "024_z000p366": {"halo":1,    "subhalo":0   },
        "025_z000p271": {"halo":1,    "subhalo":0   },
        "026_z000p183": {"halo":1,    "subhalo":0   },
        "027_z000p101": {"halo":1,    "subhalo":0   },
        "028_z000p000": {"halo":1,    "subhalo":0   }
    }

# %%
def time_from_redshift(z, omega0, omega_lambda, h):
    if omega_lambda != 0 and np.abs(omega0 - 1.0 + omega_lambda) > 10**-6:
        print(f"Omega0 = {omega0}")
        print("Omega_tot = {}".format(omega0 + omega_lambda))
        print("Descrepency = {}".format(omega0 - 1 + omega_lambda))
        raise ValueError("Invalid inputs - see output for details.")

    hTime = 9.778 / h# Gyrs

    if omega_lambda == 0:
        if omega0 == 1:
            time = (2 / 3) * hTime / ((1 + z)**1.5)
        else:
            if omega0 > 1:
                omega0_z = omega0 * z
                factor1 = omega0 / (2 * (omega0 - 1)**1.5)
                term1 = np.arccos((omega0_z - omega0 + 2) / (omega0_z + omega0))
                term2 = 2 * np.sqrt((omega0 - 1) * (omega0_z + 1) / (omega0_z + omega0))
                factor2 = term1 - term2
                time = factor1 * factor2 * hTime

            else:
                raise ValueError("Failed tryint to intergrate for open, matter dominated cosmology.")

    else:
        factor1 = (2 / 3) / np.sqrt(omega_lambda)
        term1 = np.sqrt(omega_lambda / omega0) / ((1 + z)**1.5)
        term2 = np.sqrt(1 + (omega_lambda / (omega0 * (1 + z)**3)))
        factor2 = np.log(term1 + term2)
        time = factor1 * factor2 * hTime

    return time

# %% [markdown]
# ## Routine for creating Plotting $M_{200}$ Over Time (Redshift)

# %%
sim = ("Early", "Organic", "Late")
 #define a list that contains each assembly history
def total_mass_m200(halo, subhalo, tag, sim):
 #create a class for reading the value of M200 for a given simulation    return catalogue_read("FOF", "Group_M_Crit200", data_location, tag=tag, sim=sim, cgs_units=True)[halo - 1] 

            
def create_m200_graph(func):
    mass = []
    snapshot_redshift = []
    lookback_time = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        mass.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        lookback_time.append(np.empty(shape = (len(tags), )))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")

                mass[i][j] = func(halo, subhalo, tag, sim[i])
                mass[i][j] /= (m_sun/h)
                z = float("{}.{}".format(tag[5:8], tag[9:12]))
                lookback_time[i][j] = time_from_redshift(z, omega_0, omega_lambda, h)


            except LookupError:
                mass[i][j] = None  
                

        array_filter = True ^ np.isnan(mass[i])
        mass[i] = mass[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter]
        lookback_time[i] = lookback_time[i][array_filter]
        
    fig, ax = plt.subplots(figsize=(10,10))
    ax2 = ax.twiny()
    ax.plot(lookback_time[0], mass[0], label = "GM-Early", c = '#33bbee')
    ax.plot(lookback_time[1], mass[1], label = "Organic", c = '#ee3377')
    ax.plot(lookback_time[2], mass[2], label = "GM-Late", c = '#ee7733')           
    ax.set_xlabel("Time (Gyr)")
    ax.set_ylabel("$M_{200}$ $(M_☉)$")
    ax.set_yscale('log')
    ax.tick_params(which='both', direction="in") 
    ax2.set_xlabel('$z$')  # we already handled the x-label with ax1 
    ax2.tick_params(axis='x')
    ax2.set_xscale('log')
    ax2.set_yscale('log') 
    ax2.set_xlim(1e1, 1e-1)
    ax2.yaxis.tick_right()
    ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    ax2.get_yaxis().set_visible(False)
    ax2.tick_params(which='both', direction="in")
    ax.set_title("$M_{200}$ Over Time for Each Assembly History")
    ax.yaxis.label.set_size(32)
    ax.xaxis.label.set_size(32)
    ax2.xaxis.label.set_size(32)
    ax.legend(loc='lower right',prop={'size': 20}) 
    plt.savefig('m_200_vs_time.png')
    plt.show()
    
create_m200_graph(total_mass_m200)

# %% [markdown]
# ## Routine for Finding $M_\star$ Over Time

# %%
sim = ("Early", "Organic", "Late")

def m_star(halo, subhalo, tag, sim):
    first_subhalo = catalogue_read("FOF", "FirstSubhaloID", data_location, tag=tag, sim=sim, cgs_units=True)[halo-1]
    subhalo_index = first_subhalo + subhalo 
    return catalogue_read("Subhalo", "ApertureMeasurements/Mass/030kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][4]


def create_m_star_graph(func):
    mass = []
    snapshot_redshift = []
    lookback_time = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        mass.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        lookback_time.append(np.empty(shape = (len(tags), )))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")
                
                mass[i][j] = func(halo, subhalo, tag, sim[i])
                mass[i][j] /= (m_sun/h)
                z = float("{}.{}".format(tag[5:8], tag[9:12]))
                lookback_time[i][j] = time_from_redshift(z, omega_0, omega_lambda, h)
                
            except LookupError:
                mass[i][j] = None  
                

        array_filter = True ^ np.isnan(mass[i])
        mass[i] = mass[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter] 
        lookback_time[i] = lookback_time[i][array_filter] 
        
    fig, ax = plt.subplots(figsize=(10,10))
    ax2 = ax.twiny()
    ax.plot(lookback_time[0], mass[0], label = "GM-Early", c = '#33bbee')
    ax.plot(lookback_time[1], mass[1], label = "Organic", c = '#ee3377')
    ax.plot(lookback_time[2], mass[2], label = "GM-Late", c = '#ee7733')           
    ax.set_xlabel("Time (Gyr)")
    ax.set_ylabel("$M_{\star}$ $(M_☉)$")
    ax.set_yscale('log')
    ax.tick_params(which='both', direction="in") 
    ax2.set_xlabel('$z$')  # we already handled the x-label with ax1 
    ax2.tick_params(axis='x')
    ax2.set_xscale('log')
    ax2.set_yscale('log') 
    ax2.set_xlim(1e1, 1e-1)
    ax2.yaxis.tick_right()
    ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    ax2.get_yaxis().set_visible(False)
    ax2.tick_params(which='both', direction="in")
    ax.set_title("$M_{\star}$ Over Time for Each Halo Type")
    ax.yaxis.label.set_size(32)
    ax.xaxis.label.set_size(32)
    ax2.xaxis.label.set_size(32)
    ax.legend(loc='lower right',prop={'size': 20})  
    plt.savefig('m_star_vs_time.png')
    plt.show()
    
create_m_star_graph(m_star)

# %% [markdown]
# ## Routine for Finding sSFR Over Time

# %%
def sfr(halo, subhalo, tag, sim):
    first_subhalo = catalogue_read("FOF", "FirstSubhaloID", data_location, tag=tag, sim=sim, cgs_units=True)[halo-1]
    subhalo_index = first_subhalo + subhalo 
    return catalogue_read("Subhalo", "ApertureMeasurements/SFR/030kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index]

def create_sfr_graph(func_1, func_2):
    ssfr = []
    snapshot_redshift = []
    lookback_time = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        ssfr.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        lookback_time.append(np.empty(shape = (len(tags), )))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")
                
                
                ssfr[i][j] = (func_1(halo, subhalo, tag, sim[i])/func_2(halo, subhalo, tag, sim[i])*h)*3.155e7
                z = float("{}.{}".format(tag[5:8], tag[9:12]))
                lookback_time[i][j] = time_from_redshift(z, omega_0, omega_lambda, h)
                 
            except LookupError:
                ssfr[i][j] = None  
                

        array_filter = True ^ np.isnan(ssfr[i])
        ssfr[i] = ssfr[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter] 
        lookback_time[i] = lookback_time[i][array_filter]

    count = 0
    for i in range(0, len(ssfr[0])):
        if ssfr[0][i] > 0:
            count += 1
            
    ssfr_early = np.ones(count)
    lookback_early = np.ones(count)
    count = 0
    for i in range(0, len(ssfr[0])):
        if ssfr[0][i] > 0:
            ssfr_early[count] = ssfr[0][i]
            lookback_early[count] = lookback_time[0][i]
            count += 1
            
    count = 0
    for i in range(0, len(ssfr[1])):
        if ssfr[1][i] > 0:
            count += 1
            
    ssfr_organic = np.ones(count)
    lookback_organic = np.ones(count)
    count = 0
    for i in range(0, len(ssfr[1])):
        if ssfr[1][i] > 0:
            ssfr_organic[count] = ssfr[1][i]
            lookback_organic[count] = lookback_time[1][i]
            count += 1
            
    count = 0
    for i in range(0, len(ssfr[2])):
        if ssfr[2][i] > 0:
            count += 1
            
    ssfr_late = np.ones(count)
    lookback_late = np.ones(count)
    count = 0
    for i in range(0, len(ssfr[2])):
        if ssfr[2][i] > 0:
            ssfr_late[count] = ssfr[2][i]
            lookback_late[count] = lookback_time[2][i]
            count += 1
    
    print(min(ssfr_early)) 
    print(min(ssfr_organic)) 
    print(min(ssfr_late)) 
    fig, ax = plt.subplots(figsize=(10,10))
    ax2 = ax.twiny()
    ax.plot(lookback_early, ssfr_early, label = "GM-Early", c = '#33bbee')
    ax.plot(lookback_organic, ssfr_organic, label = "Organic", c = '#ee3377')
    ax.plot(lookback_late, ssfr_late, label = "GM-Late", c = '#ee7733')           
    ax.set_xlabel("Time (Gyr)")
    ax.set_ylabel("sSFR ($yr^{-1}$)")
    ax.set_yscale('log')
    ax.tick_params(which='both', direction="in") 
    ax2.set_xlabel('$z$')  # we already handled the x-label with ax1 
    ax2.tick_params(axis='x')
    ax2.set_xscale('log')
    ax2.set_yscale('log') 
    ax2.set_xlim(1e1, 1e-1)
    ax2.yaxis.tick_right()
    ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    ax2.get_yaxis().set_visible(False)
    ax2.tick_params(which='both', direction="in")
    ax.set_title("sSFR Over Time for Each Halo Type")
    ax.yaxis.label.set_size(32)
    ax.xaxis.label.set_size(32)
    ax2.xaxis.label.set_size(32)
    ax.legend(loc='upper right',prop={'size': 20})  
    plt.savefig('ssfr_vs_time.png')
    plt.show()
    
create_sfr_graph(sfr, m_star)
# Out:
# C:\Users\Ryan\AppData\Local\Temp/ipykernel_25928/2118490809.py:25: RuntimeWarning: invalid value encountered in double_scalars
#   ssfr[i][j] = (func_1(halo, subhalo, tag, sim[i])/func_2(halo, subhalo, tag, sim[i])*h)*3.155e7
# 1.9405598367656718e-13
# 3.1678039166315893e-11
# 9.618390283005415e-11

# %% [markdown]
# ## Routine for Plotting Total Black Hole Mass Over Time

# %%
sim = ("Early", "Organic", "Late")

def m_bh(halo, subhalo, tag, sim):
    first_subhalo = catalogue_read("FOF", "FirstSubhaloID", data_location, tag=tag, sim=sim, cgs_units=True)[halo-1]
    subhalo_index = first_subhalo + subhalo 
    return catalogue_read("Subhalo", "ApertureMeasurements/Mass/100kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][5]


def create_m_bh_graph(func):
    mass = []
    snapshot_redshift = []
    lookback_time = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        mass.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        lookback_time.append(np.empty(shape = (len(tags), )))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")
                
                mass[i][j] = func(halo, subhalo, tag, sim[i])
                mass[i][j] /= (m_sun/h)
                z = float("{}.{}".format(tag[5:8], tag[9:12]))
                lookback_time[i][j] = time_from_redshift(z, omega_0, omega_lambda, h)

                
            except LookupError:
                mass[i][j] = None  
                

        array_filter = True ^ np.isnan(mass[i])
        mass[i] = mass[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter] 
        lookback_time[i] = lookback_time[i][array_filter]
    
    print(max(mass[0]))
    print(max(mass[1]))
    print(max(mass[2]))
    fig, ax = plt.subplots(figsize=(10,10))
    ax2 = ax.twiny()
    ax.plot(lookback_time[0], mass[0], label = "GM-Early", c = '#33bbee')
    ax.plot(lookback_time[1], mass[1], label = "Organic", c = '#ee3377')
    ax.plot(lookback_time[2], mass[2], label = "GM-Late", c = '#ee7733')           
    ax.set_xlabel("Time (Gyr)")
    ax.set_ylabel("$M_{BH}$ $(M_☉)$")
    ax.set_yscale('log')
    ax.tick_params(which='both', direction="in") 
    ax2.set_xlabel('$z$')  # we already handled the x-label with ax1 
    ax2.tick_params(axis='x')
    ax2.set_xscale('log')
    ax2.set_yscale('log') 
    ax2.set_xlim(1e1, 1e-1)
    ax2.yaxis.tick_right()
    ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    ax2.get_yaxis().set_visible(False)
    ax2.tick_params(which='both', direction="in")
    ax.set_title("$M_{BH}$ Over Time for Each Assembly History")
    ax.yaxis.label.set_size(28)
    ax.xaxis.label.set_size(28)
    ax2.xaxis.label.set_size(28)
    ax.legend(loc='upper left',prop={'size': 20})  
    plt.savefig('m_bh_vs_time.jpeg')
    plt.show()
    
create_m_bh_graph(m_bh)
# Out:
# 509660120.472312
# 57304320.84109634
# 24086688.52527626

# %% [markdown]
# ## Creating a Routine for Finding $f_{CGM}/(\Omega_{b}/\Omega_{0})$ Against Time

# %%
def m_cgm(halo, subhalo, tag, sim):
    first_subhalo = catalogue_read("FOF", "FirstSubhaloID", data_location, tag=tag, sim=sim, cgs_units=True)[halo-1]
    subhalo_index = first_subhalo + subhalo 
    m_gas = catalogue_read("Subhalo", "ApertureMeasurements/Mass/100kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][0]
    m_dm = catalogue_read("Subhalo", "ApertureMeasurements/Mass/100kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][1]
    m_star = catalogue_read("Subhalo", "ApertureMeasurements/Mass/100kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][4]
    m_bh = catalogue_read("Subhalo", "ApertureMeasurements/Mass/100kpc", data_location, tag=tag, sim=sim, cgs_units=True)[subhalo_index][5]
    total_cgm = (m_gas)/(m_gas+m_dm+m_star+m_bh)
    return total_cgm /((m_gas+m_star)/(m_gas+m_dm+m_star+m_bh))


def create_m_cgm_graph(func):
    f_cgm = []
    snapshot_redshift = []
    lookback_time = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        f_cgm.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        lookback_time.append(np.empty(shape = (len(tags), )))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")
                
                f_cgm[i][j] = func(halo, subhalo, tag, sim[i])
                f_cgm[i][j] /= 1/h
                z = float("{}.{}".format(tag[5:8], tag[9:12]))
                lookback_time[i][j] = time_from_redshift(z, omega_0, omega_lambda, h)
                
            except LookupError:
                f_cgm[i][j] = None  
                

        array_filter = True ^ np.isnan(f_cgm[i])
        f_cgm[i] = f_cgm[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter] 
        lookback_time[i] = lookback_time[i][array_filter]
    
    print(f_cgm[0][len(f_cgm[0])-1])
    print(min(f_cgm[1]))
    print(min(f_cgm[2]))
    fig, ax = plt.subplots(figsize=(10,10))
    ax2 = ax.twiny()
    ax.plot(lookback_time[0], f_cgm[0], label = "GM-Early", c = '#33bbee')
    ax.plot(lookback_time[1], f_cgm[1], label = "Organic", c = '#ee3377')
    ax.plot(lookback_time[2], f_cgm[2], label = "GM-Late", c = '#ee7733')           
    ax.set_xlabel("Time (Gyr)")
    ax.set_ylabel("$f_{CGM}/(\Omega_{b}/\Omega_{0})$")
    ax.set_ylim([0, 0.8])
    ax.set_yticks(np.arange(0, 1, 0.2))
    ax.tick_params(which='both', direction="in") 
    ax2.set_xlabel('$z$')  # we already handled the x-label with ax1 
    ax2.tick_params(axis='x')
    ax2.set_xscale('log')
    ax2.set_xlim(1e1, 1e-1)
    ax2.yaxis.tick_right()
    ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    ax2.get_yaxis().set_visible(False)
    ax2.tick_params(which='both', direction="in")
    ax.set_title("$f_{CGM}/(\Omega_{b}/\Omega_{0})$ Over Time for Each Assembly History")
    ax.yaxis.label.set_size(32)
    ax.xaxis.label.set_size(32)
    ax2.xaxis.label.set_size(32)
    ax.legend(loc='upper right',prop={'size': 20})  
    plt.savefig('fcgm_vs_time.jpeg')
    plt.show()
    
create_m_cgm_graph(m_cgm)
# Out:
# 0.09542591278793074
# 0.11561176152453494
# 0.2854144414215593

# %% [markdown]
# ## Creating a Routine for finding $\kappa_{co}$
#
# ### $\kappa_{co} = \frac{K_{co}^{rot}}{K} = \frac{1}{K} \displaystyle\sum_{i, L_{z,i}} \frac{1}{2}m_{i} \left(\frac{L_{z,i}}{m_{i}R_{i}} \right)^2$
#
# ### Where $K = \displaystyle\sum_{i} \frac{1}{2}m_{i}v_{i}^2$

# %%
galaxy_physical_positions = {}

def k_co(halo, subhalo, tag, sim):
    galaxy_centre = galaxy_physical_positions[sim][tag]
    if galaxy_centre is None:
        raise LookupError("No data avalible.")
    
    snapfile = os.path.join(data_location , model , sim , f'snapshot_{tag}', f'snap_{tag}.{}.hdf5')
    snapshot = pyread_eagle.EagleSnapshot(snapfile)


def create_k_co_graph(func):
    mass = []
    snapshot_redshift = []

    for i, simulation in enumerate((assembly_history_early, assembly_history_organic, assembly_history_late)):
        
        mass.append(np.empty(shape = (len(tags), )))
        snapshot_redshift.append(np.array([float("{}.{}".format(tag[5:8], tag[9:12]))for tag in tags]))
        for j, tag in enumerate(tags):
            try:
                halo = simulation[tag]["halo"]
                subhalo = simulation[tag]["subhalo"]

                if halo is None:
                    raise LookupError("No history avalible.")
                
                mass[i][j] = func(halo, subhalo, tag, sim[i])
                mass[i][j] /= (m_sun/h)

                
            except LookupError:
                mass[i][j] = None  
                

        array_filter = True ^ np.isnan(mass[i])
        mass[i] = mass[i][array_filter]
        snapshot_redshift[i] = snapshot_redshift[i][array_filter] 
    
    
    plt.plot(snapshot_redshift[0], mass[0], label = "Early")
    plt.plot(snapshot_redshift[1], mass[1], label = "Organic")
    plt.plot(snapshot_redshift[2], mass[2], label = "Late")           
    plt.xlabel("z")
    plt.ylabel("$M_{bh}$ (M☉)")
    plt.gca().invert_xaxis()
    plt.xscale('log')
    plt.yscale('log') 
    plt.title("$M_{bh}$ Over Time for Each Snapshot")
    plt.legend()
    plt.show()
    
create_k_co_graph(m_bh)

# %%
def kinematics_diagnostics(XYZ,mass,Vxyz,PBE,aperture=0.03,CoMvelocity=True):
    """
    Compute the various kinematics diagnostics.
    Returns the kinematics diagnostics for the input particles.
    Parameters
    ----------
    XYZ : array_like of dtype float, shape (n, 3)
        Particles coordinates (in unit of length L) such that XYZ[:,0] = X,
        XYZ[:,1] = Y & XYZ[:,2] = Z
    mass : array_like of dtype float, shape (n, )
        Particles masses (in unit of mass M)
    Vxyz : array_like of dtype float, shape (n, 3)
        Particles coordinates (in unit of velocity V) such that Vxyz[:,0] = Vx,
        Vxyz[:,1] = Vy & Vxyz[:,2] = Vz
    PBE : array_like of dtype float, shape (n, )
        Particles specific binding energies
    aperture : float, optional
        Aperture (in unit of length L) for the computation. Default is 0.03 L
    CoMvelocity : bool, optional
        Boolean to allow the centering of velocities by the considered particles
        centre-of-mass velocity. Default to True
    Returns
    -------
    kappa : float
        The kinetic energy fraction invested in co-rotation.
    discfrac : float
        The disc-to-total mass fraction estimated from the counter-rotating
        bulge.
    orbi : float
        The median orbital circularity of the particles values.
    vrotsig : float
        The rotation-to-dispersion ratio .
    delta : float
        The dispersion anisotropy.
    zaxis : array of dtype float, shape (3, )
        The unit vector of the momentum axis (pointing along the momentum direction).
    Momentum : float
        The momentum magnitude (in unit M.L.V).
    """
    particlesall = np.vstack([XYZ.T,mass,Vxyz.T,PBE]).T
    # Compute distances
    distancesall = np.linalg.norm(particlesall[:,:3],axis=1)
    # Restrict particles
    extract = (distancesall<aperture)
    particles = particlesall[extract].copy()
    distances = distancesall[extract].copy()
    Mass = np.sum(particles[:,3])
    if CoMvelocity:
        # Compute CoM velocty & correct
        dvVmass = np.nan_to_num(np.sum(particles[:,3][:,np.newaxis]*particles[:,4:7],axis=0)/Mass)
        particlesall[:,4:7]-=dvVmass
        particles[:,4:7]-=dvVmass
    # Compute momentum
    smomentums = np.cross(particles[:,:3],particles[:,4:7])
    momentum = np.sum(particles[:,3][:,np.newaxis]*smomentums,axis=0)
    Momentum = np.linalg.norm(momentum)
    # Compute cylindrical quantities
    zaxis = (momentum/Momentum)
    zheight = np.sum(zaxis*particles[:,:3],axis=1)
    cylposition = particles[:,:3]-zheight[:,np.newaxis]*[zaxis]
    cyldistances = np.sqrt(distances**2-zheight**2)
    smomentumz = np.sum(zaxis*smomentums,axis=1)
    vrots = smomentumz/cyldistances
    vrads = np.sum(cylposition*particles[:,4:7]/cyldistances[:,np.newaxis],axis=1)
    vheis = np.sum(zaxis*particles[:,4:7],axis=1)
    # Compute co-rotational kinetic energy fraction
    Mvrot2 = np.sum((particles[:,3]*vrots**2)[vrots>0])
    kappa = Mvrot2/np.sum(particles[:,3]*(np.linalg.norm(particles[:,4:7],axis=1))**2)
    # Compute disc-to-total ratio
    discfrac = 1-2*np.sum(particles[vrots<=0,3])/Mass
    # Compute orbital circularity
    sbindingenergy = particles[:,7]; sortE = np.argsort(sbindingenergy); unsortE = np.argsort(sortE)
    jzE = np.vstack([sbindingenergy,smomentumz]).T[sortE]
    orbital = (jzE[:,1]/np.maximum.accumulate(np.abs(jzE[:,1])))[unsortE]
    orbi = np.median(orbital)
    # Compute rotation-to-dispersion and dispersion anisotropy
    Vrot = np.abs(cumsummedian(vrots,weights=particles[:,3]))
    SigmaXY = np.sqrt(np.average(np.sum(particles[:,[3]]*np.vstack([vrads,vrots]).T**2,axis=0)/Mass))#
    SigmaO = np.sqrt(SigmaXY**2-.5*Vrot**2)
    SigmaZ = np.sqrt(np.average(vheis**2,weights=particles[:,3]))
    vrotsig = Vrot/SigmaO
    delta = 1-(SigmaZ/SigmaO)**2
    # Return
    return kappa,discfrac,orbi,vrotsig,delta,zaxis,Momentum

sim = 'Organic'
model = 'RECAL'
tag = '028_z000p000'

p, q = 3, 3
all_coords = [[0 for x in range(p)] for y in range(q)]
filenum = 0

view_box = [0.02, 0.02, 0.02]
boxsize = (snapshot.boxsize)/h
centre = [28.326, 2.614, 21.519]
for i in range(0, 3):
    centre[i] = centre[i]/h

lower_bounds = [28.326, 2.614, 21.519]
for i in range(0, 3):
    lower_bounds[i] -= view_box[i]

upper_bounds = [28.326, 2.614, 21.519]
for i in range(0, 3):
    upper_bounds[i] += view_box[i]

#for tag in tags:
    
#    for i in range(-1, 15):

#        snapfile = os.path.join(data_location , model , sim , f'snapshot_{tag}', f'snap_{tag}.{filenum}.hdf5')
#        snapshot = pyread_eagle.EagleSnapshot(snapfile)
#
#        coords = particle_read(0, "Coordinates", lower_bounds, upper_bounds, data_location, snapshot, centre = centre, model = model, sim = sim, tag = tag)
#        coords_centre_adjusted = coords - centre
#        coords_box_wrapped = ((coords_centre_adjusted + (boxsize/2)) % boxsize) - (boxsize/2)
#        all_coords = np.concatenate((all_coords, coords_box_wrapped))
        
#        filenum += 1

#XYZ = all_coords
#print(XYZ)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19040/1304373970.py in <module>
#     113         snapshot = pyread_eagle.EagleSnapshot(snapfile)
#     114
# --> 115         coords = particle_read(0, "Coordinates", lower_bounds, upper_bounds, data_location, snapshot, centre = centre, model = model, sim = sim, tag = tag)
#     116         coords_centre_adjusted = coords - centre
#     117         coords_box_wrapped = ((coords_centre_adjusted + (boxsize/2)) % boxsize) - (boxsize/2)
#
# ~\AppData\Local\Temp/ipykernel_19040/2755378364.py in particle_read(ptype, quantity, lower_bounds, upper_bounds, data_location, snapshot, centre, sim, model, tag, phys_units, cgs_units, verbose)
#      39                 print('No particles of type ',ptype,' in snapfile ',snapfile_ind)
#      40             snapfile_ind += 1
# ---> 41             continue
# ...
